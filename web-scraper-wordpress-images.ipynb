# %% [markdown]
# # Free Site to Site Migration Script for Wordpress
#
# This script will help you to migrate posts, pages including a large volume of images from one Wordpress site to another without the use of any (paid) Wordpress migration plug-ins.
#
# **Prerequisites:**
#
# 1. You have exported the posts, pages, comments, ... from your current Wordpress site via the standard `Wordpress Tools -> Export` functionality
# 2. You have installed the free plugin https://wordpress.org/plugins/media-sync/ (or similar) on your target Wordpress site
#
# **Key steps of the script:**
#
# - You need to manually define the input file name(s) and local output folder(s) as variables at the beginning of the script (`chapter 0 - Set Variables`)
# - The script automatically identifies all potential image URLs (`chapter 2 - Extract Image URLs`)
# - The script downloads all identified images into the earlier specified folder (`chapter 3 - Download all Images`)
# - The script modifies the original image URLs within the Wordpress export xml file and replaces it with the newly generated image file name and location (`chapter 4 - Replace Original Image URLs with new Image URLs`)
#
# **Output after executing the script:**
#
# - All identified images are stored locally in the folder that you specified
# - A copy of the original Wordpress export xml file including the modified / new image urls is stored locally
#
# **Todo after script has executed:**
#
# - You must now manually upload all your downloaded images into the target folder of your target Wordpress installation that you specified at the beginning of this notebook (e.g. via FTP client)
# - Import the newly generated Wordpress xml file via the standard `Wordpress Tools -> Import` functionality
# - Don't forget to refresh the media library in Wordpress (e.g. using this plugin: https://wordpress.org/plugins/media-sync/)

# %%
import requests
import re
import shutil
import validators
import pandas as pd
import hashlib
import os

# %% [markdown]
# ## 0 - Set Variables
#
# First, we need to set some basic parameters to better organize the downloaded images and the modified Wordpress xml export files. In case you have a large amount of posts and images, it is highly recommended that you structure the downloads by year, or even month-year.

# %%
# Define your target upload folder for Wordpress
WORDPRESS_UPLOAD_FOLDER = '/wp-content/uploads/history/year-2023/'
# Define target download folder (locally) to store all detected images
IMAGE_DOWNLOAD_FOLDER = 'extracted-images/year-2023/'
# The name and path of the original wordpress export xml
wordpress_filename_original = './your-personal-export-file-from-current-wordpress-site.xml'
# The name and path of the target (modified) wordpress export xml
wordpress_filename_target = './year-2023.xml'

# %% [markdown]
# ## 1 - Functions
#
# The following functions are required:
#
# - **get_url_images_in_text(text):** Returns a simple list of URLs available in the provided text
# - **get_file_name(url):** Returns only the file name of the file mentioned in the given URL (strips content prior the last occurrence of character "\\")
# - **construct_file_name(url):** Generates a new file name which is based on a stripped down version of the original URL. The original file name is retained and a unique hash value is added (in case the same file name exists in different folders / URLs)
# - **download_file(url,file_name):** Downloads the file available under url into file_name

# %%
def get_url_images_in_text(text):
    url_candidates = []
    # First round of regex based cleaning:
    pattern = r'[\=,\(][\"|\'].[^\=\"]+\.(?i:jpg|gif|png|bmp|jpeg)[\"|\']'
    results = re.findall(pattern,text,re.IGNORECASE)
    for x in results:
      x = x.replace('="', '')
      x = x.replace('"', '')
      x = x.replace('\'', '')
      url_candidates.append(x)
    # Another regex check to filter out the URLs (since some slipped through the pattern above)
    urls = []
    for y in url_candidates:
      results = re.findall(r'(https?://\S+)', y)
      for x in results:
        urls.append(x)
    return urls

def get_file_name(url):
  firstpos=url.rfind("/")
  lastpos=len(url)
  return url[firstpos+1:lastpos]

def construct_file_name(url):
  hashvalue = hashlib.sha1(url.encode('utf-8')).hexdigest()
  file_name = get_file_name(url)
  return hashvalue+file_name

def download_file(url,file_name):
  if validators.url(url):
    response = requests.get(url, stream = True)
    if response.status_code == 200:
      # Create directory if it does not yet exist
      os.makedirs(os.path.dirname(file_name), exist_ok=True)
      # Write content from response to file
      with open(file_name,'wb') as f:
        shutil.copyfileobj(response.raw, f)
      print('Image sucessfully downloaded: ',file_name)
    else:
      print('Image couldn\'t be retrieved')
  else:
    print(f'URL {url} is not valid')

# %% [markdown]
# ## 2 - Extract Image URLs
#
# Script opens the original Wordpress export xml (stored in variable wordpress_filename_original) and identifies all relevant lines that contain image URLs. For each line, the script extracts the image related URLs. Those URLs are stored within a Pandas dataframe. The dataframe contains the following information:
# - **index:** index number starting from 0
# - **line:** original line number where the image URL was discovered within the Wordpress xml file
# - **original_image_url:** the URL of the original image
# - **new_image_file_name:** the file name of the new image
# - **new_image_url:** the URL pointing to the new image

# %%
image_urls = []
# Words to look for in each line
words = ['.jpg','jpeg', '.png','.JPG', '.JPEG', '.PNG']
with open(wordpress_filename_original, 'r') as fp:
    for l_no, line in enumerate(fp):
        # Search if line contains any images based on the suffixes above
        for word in words:
            if word in line:
                # Extract URLs using the above custom function
                image_urls_in_line = get_url_images_in_text(line)
                # Remove potential duplicates (same URL could be mentioned multiple times in single line)
                image_urls_in_line = list(dict.fromkeys(image_urls_in_line))
                # Add list of URLS within line to the image url list
                for image_url in image_urls_in_line:
                    row = []
                    row.append(str(l_no))
                    row.append(image_url)
                    image_urls.append(row)
df_image_urls = pd.DataFrame(image_urls)
df_image_urls.columns =['line','original_image_url']
df_image_urls['new_image_file_name'] = df_image_urls['original_image_url'].apply(lambda x: construct_file_name(x))
df_image_urls['new_image_url'] = df_image_urls['new_image_file_name'].apply(lambda x: WORDPRESS_UPLOAD_FOLDER + x)

# %% [markdown]
# ## 3 - Download all Images
#
# All images stored in dataframe `df_image_url` are downloaded into the folder specified in variable `IMAGE_DOWNLOAD_FOLDER`.

# %%
for image_url in image_urls:
    file_name = construct_file_name(image_url[1])
    print(file_name)
    download_file(image_url[1], IMAGE_DOWNLOAD_FOLDER+file_name)
# Out:
# 1a18246f360cfa8ec97b83c2935e6cce5e535ea9stilouette-gift-click-here-4.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/1a18246f360cfa8ec97b83c2935e6cce5e535ea9stilouette-gift-click-here-4.jpg
# 6238f81780e3e46d403a01b7664867d1dfe1dd65stilouette-voucher.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/6238f81780e3e46d403a01b7664867d1dfe1dd65stilouette-voucher.jpg
# 2bc638543b7760e35765db8a225c01c88e0e580dIMG_0150-1024x683.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/2bc638543b7760e35765db8a225c01c88e0e580dIMG_0150-1024x683.jpg
# 2a49286219eba226b7c5bb34f7130d39ee04866dstilouette-kids-school-extract.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/2a49286219eba226b7c5bb34f7130d39ee04866dstilouette-kids-school-extract.jpg
# e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# Image sucessfully downloaded:  extracted-images/all-pages/e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# Image sucessfully downloaded:  extracted-images/all-pages/e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# Image sucessfully downloaded:  extracted-images/all-pages/e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# Image sucessfully downloaded:  extracted-images/all-pages/e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# 6542cd0d984f73447d719f8a5eb34a6d6992661bstilouette-color-gift.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/6542cd0d984f73447d719f8a5eb34a6d6992661bstilouette-color-gift.jpg
# bc0460a8d3abb31ac59fdb98d6528962dfb15f74Bildschirmfoto-2020-12-30-um-16.55.56-300x212.png
# Image sucessfully downloaded:  extracted-images/all-pages/bc0460a8d3abb31ac59fdb98d6528962dfb15f74Bildschirmfoto-2020-12-30-um-16.55.56-300x212.png
# 87ad9b4ff996d183fed6a19e0c7431090684924bПростодушный.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/87ad9b4ff996d183fed6a19e0c7431090684924bПростодушный.jpg
# 0d02bf0889d2690f3041b685d04244d1107d426eСлавный-Малый.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/0d02bf0889d2690f3041b685d04244d1107d426eСлавный-Малый.jpg
# aabd7c8f9a762ae5ed71961671c356d317432e1aЭстет.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/aabd7c8f9a762ae5ed71961671c356d317432e1aЭстет.jpg
# 84a8850ccb568bdc9db76bd5a984bd728057a90eШут.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/84a8850ccb568bdc9db76bd5a984bd728057a90eШут.jpg
# 1d76317d51b5aff11c23c4123e938e08f2ff6840Воин.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/1d76317d51b5aff11c23c4123e938e08f2ff6840Воин.jpg
# bd0121197eda9d3963eefdc9d988e63d71afa579Бунтарь.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/bd0121197eda9d3963eefdc9d988e63d71afa579Бунтарь.jpg
# dc1cacf827cd17fa9bf07d708298b3283c9fdf36Правитель.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/dc1cacf827cd17fa9bf07d708298b3283c9fdf36Правитель.jpg
# 9f1659c8365b5eca7843ce6f798e28d14846a391Искатель.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/9f1659c8365b5eca7843ce6f798e28d14846a391Искатель.jpg
# 0fb2b6c9c83a41aeb7a299d1a540f1657c666742Опекун.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/0fb2b6c9c83a41aeb7a299d1a540f1657c666742Опекун.jpg
# 2e1660a74118fae3a62b77d21ecab85830855960Мудрец.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/2e1660a74118fae3a62b77d21ecab85830855960Мудрец.jpg
# 9edf32686e8fc64a58b4719f52a7bf8cb85b8bf8Маг.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/9edf32686e8fc64a58b4719f52a7bf8cb85b8bf8Маг.jpg
# a29811311a1e07b6a41de33fb9e70eca3286312cТворец.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/a29811311a1e07b6a41de33fb9e70eca3286312cТворец.jpg
# 3beaccde1e39edf4124f5ac6919199c84def8182Bildschirmfoto-2016-11-21-um-21.54.52.png
# Image sucessfully downloaded:  extracted-images/all-pages/3beaccde1e39edf4124f5ac6919199c84def8182Bildschirmfoto-2016-11-21-um-21.54.52.png
# 3cb19496d00890a4d56858b7a4ff1b0b2c914d8fFotorCreated-1.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/3cb19496d00890a4d56858b7a4ff1b0b2c914d8fFotorCreated-1.jpg
# e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# Image sucessfully downloaded:  extracted-images/all-pages/e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# Image sucessfully downloaded:  extracted-images/all-pages/e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# Image sucessfully downloaded:  extracted-images/all-pages/e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# Image sucessfully downloaded:  extracted-images/all-pages/e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# Image sucessfully downloaded:  extracted-images/all-pages/e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# Image sucessfully downloaded:  extracted-images/all-pages/e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# Image sucessfully downloaded:  extracted-images/all-pages/e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# Image sucessfully downloaded:  extracted-images/all-pages/e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# Image sucessfully downloaded:  extracted-images/all-pages/e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# Image sucessfully downloaded:  extracted-images/all-pages/e7f2524c0e98b886af438eddebecd53e3f907138stilouette-question.png
# 884033834b78796c779b43b0a3f70fdcfd0e6f43gift-3-300x225.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/884033834b78796c779b43b0a3f70fdcfd0e6f43gift-3-300x225.jpg
# 776e0e16af1e930d581e66db42c1ab33a7706b34gift-2-300x225.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/776e0e16af1e930d581e66db42c1ab33a7706b34gift-2-300x225.jpg
# 769b7bfe7c76faa31b07801a561e01c6a9afd23bantwerpen.png
# Image sucessfully downloaded:  extracted-images/all-pages/769b7bfe7c76faa31b07801a561e01c6a9afd23bantwerpen.png
# 75b34edca0aa0176d9e22fd4162ef0712d2dc13eMyCollages-14.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/75b34edca0aa0176d9e22fd4162ef0712d2dc13eMyCollages-14.jpg
# 75b34edca0aa0176d9e22fd4162ef0712d2dc13eMyCollages-14.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/75b34edca0aa0176d9e22fd4162ef0712d2dc13eMyCollages-14.jpg
# 4e6b4bc9a9d06d2ad24197039bab2ef95b2321e4MyCollages-14-1.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/4e6b4bc9a9d06d2ad24197039bab2ef95b2321e4MyCollages-14-1.jpg
# e9f152bb6ab4913b8697947c4a6280c317fd45e2MyCollages-14-2.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/e9f152bb6ab4913b8697947c4a6280c317fd45e2MyCollages-14-2.jpg
# 795f8f65c5c9277e209c5df30538c31a4ec44d3fMyCollages-14-3.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/795f8f65c5c9277e209c5df30538c31a4ec44d3fMyCollages-14-3.jpg
# 9ebabee344b2bc76f200077af5aa7300dd4a6cadMyCollages-14-4.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/9ebabee344b2bc76f200077af5aa7300dd4a6cadMyCollages-14-4.jpg
# c60e71e79dbedbbba3775aa4c74a2f6e928f4a52MyCollages-14-5.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/c60e71e79dbedbbba3775aa4c74a2f6e928f4a52MyCollages-14-5.jpg
# 37c519ab81738ad3fdf66f6b195e11474f1b0707MyCollages-14-6.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/37c519ab81738ad3fdf66f6b195e11474f1b0707MyCollages-14-6.jpg
# 87c3c0ba018676ff2bd24d4c64b481397fba83acMyCollages-14-7.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/87c3c0ba018676ff2bd24d4c64b481397fba83acMyCollages-14-7.jpg
# 52619f431711c706ffbdbfd46044d25a023b9e44MyCollages-14-8.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/52619f431711c706ffbdbfd46044d25a023b9e44MyCollages-14-8.jpg
# 541a42a632aa4a692dc99382107d5c3e2ccc9957MyCollages-15.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/541a42a632aa4a692dc99382107d5c3e2ccc9957MyCollages-15.jpg
# 25356dfd7e77edc4afad3c1dad9a530c84bc28e1MyCollages-14-9.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/25356dfd7e77edc4afad3c1dad9a530c84bc28e1MyCollages-14-9.jpg
# 849737872e8592f6d91c7550aa684fbe59a47ac8MyCollages-14-10.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/849737872e8592f6d91c7550aa684fbe59a47ac8MyCollages-14-10.jpg
# 88ccf7a1090d23faac4d44c6234b0b744fe34ae1irina-korunkova.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/88ccf7a1090d23faac4d44c6234b0b744fe34ae1irina-korunkova.jpg
# ea7f7204a0a605ef391f9f86aa2acf5fd7681b97IMG_0148-1024x683.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/ea7f7204a0a605ef391f9f86aa2acf5fd7681b97IMG_0148-1024x683.jpg
# 204efabc004d3880b6aaaf547642f3c7d824b83bMyCollages-5.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/204efabc004d3880b6aaaf547642f3c7d824b83bMyCollages-5.jpg
# 01faeef25872ef80fedfba0b3098e48a606d60c0IMG_0096-683x1024.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/01faeef25872ef80fedfba0b3098e48a606d60c0IMG_0096-683x1024.jpg
# 0e2ffbf577b74bc3e8b3361b47c794c108229e0fIMG_0161-854x1024.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/0e2ffbf577b74bc3e8b3361b47c794c108229e0fIMG_0161-854x1024.jpg
# d458d99aaf54d4f45137fa7ab42c80cdd41fe544MyCollages-3-1024x585.jpg
# Image sucessfully downloaded:  extracted-images/all-pages/d458d99aaf54d4f45137fa7ab42c80cdd41fe544MyCollages-3-1024x585.jpg

# %% [markdown]
# ## 4 - Replace Original Image URLs with new Image URLs
#
# In the final step, a new Wordpress xml file is generated that has replaced all the previous image URLs with the newly generated URLs. The file is written to the location you specified in variable `wordpress_filename_target`.

# %%
target_file= open(wordpress_filename_target,'w+')
# Iterate line-by-line through the original wordpress export file
with open(wordpress_filename_original, 'r') as fp:
    for l_no, line in enumerate(fp):
        df_images_in_line = df_image_urls.query(f'line == "{l_no}"')
        # Check if any changes are required for the current line
        if df_images_in_line.size > 0:
            images_list = df_images_in_line.values.tolist()
            # Replace all original images (image[1]) with the new image urls (image[3])
            for image in images_list:
                line = line.replace(image[1],image[3])
                print(f'Line {l_no} updated')
        # Write either unchanged or changed line to the new file
        target_file.write(line)
target_file.close()
# Out:
# Line 1072 updated
# Line 1076 updated
# Line 1254 updated
# Line 2165 updated
# Line 2238 updated
# Line 2241 updated
# Line 2246 updated
# Line 2250 updated
# Line 2417 updated
# Line 2493 updated
# Line 2503 updated
# Line 2505 updated
# Line 2507 updated
# Line 2509 updated
# Line 2511 updated
# Line 2513 updated
# Line 2515 updated
# Line 2517 updated
# Line 2519 updated
# Line 2521 updated
# Line 2523 updated
# Line 2525 updated
# Line 2695 updated
# Line 2763 updated
# Line 2767 updated
# Line 2770 updated
# Line 2773 updated
# Line 2777 updated
# Line 2780 updated
# Line 2783 updated
# Line 3203 updated
# Line 3206 updated
# Line 3210 updated
# Line 3214 updated
# Line 3427 updated
# Line 3428 updated
# Line 3631 updated
# Line 3796 updated
# Line 3934 updated
# Line 3936 updated
# Line 3938 updated
# Line 3940 updated
# Line 3942 updated
# Line 3944 updated
# Line 3946 updated
# Line 3948 updated
# Line 3950 updated
# Line 3952 updated
# Line 3954 updated
# Line 3956 updated
# Line 4043 updated
# Line 4325 updated
# Line 5673 updated
# Line 5824 updated
# Line 5828 updated
# Line 6072 updated
